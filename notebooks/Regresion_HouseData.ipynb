# %% [markdown]
# # Regresión Supervisada — King County House Data
#
# Predicción del **precio** de viviendas en King County (Seattle) a partir de sus
# características usando múltiples algoritmos de regresión.
#
# ### Flujo de trabajo
# ```
# mf.Regresion(df, 'price')       # 1. Crear objeto con DataFrame
#     ↓ métodos EDA heredados      # 2. Limpiar y preparar
# reg.preparar_datos()             # 3. Split + escalado
# reg.regresion_*()                # 4. Entrenar y evaluar modelos
# reg.benchmark()                  # 5. Comparar todos los algoritmos
# ```

# %% [markdown]
# ## 1. Importación de librerías

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0, '..')
import pckEDA as mf

# %matplotlib inline
print('Clase Regresion disponible:', mf.Regresion)

# %% [markdown]
# ## 2. Carga de datos

# %%
df = pd.read_csv('../datasets/kc_house_data.csv')

reg = mf.Regresion(df, 'price')
reg.mostrarTamaño()
reg.muestraTiposDeDatos()

# %%
reg.muestraPrimerosValores(5)

# %% [markdown]
# ## 3. Limpieza y preparación de datos

# %%
# Eliminar columnas no predictivas
reg.eliminarColumnas(['id', 'date'])
reg.mostrarTamaño()

# %%
# Verificar y eliminar nulos
reg.eliminarNulos()

# %%
reg.estadisticasDescriptivas()

# %% [markdown]
# ## 4. Resumen de la variable objetivo

# %%
reg.resumen_var_pred()

# %% [markdown]
# ## 5. Preparación train/test

# %%
reg.preparar_datos(test_size=0.25, random_state=42)

print(f'Train: {reg.X_train_escalado.shape}')
print(f'Test:  {reg.X_test_escalado.shape}')

# %% [markdown]
# ## 6. Modelos de regresión

# %% [markdown]
# ### 6.1 Regresión Lineal Simple (sqft_living)

# %%
err_simple = reg.regresion_lineal_simple('sqft_living')
err_simple

# %% [markdown]
# ### 6.2 Regresión Lineal Múltiple

# %%
err_mult = reg.regresion_lineal_multiple()
err_mult

# %% [markdown]
# ### 6.3 Comparación Lasso vs. Lasso Óptimo

# %%
comp_lasso = reg.comparacion_lasso()

# %% [markdown]
# ### 6.4 Comparación Ridge vs. Ridge Óptimo

# %%
comp_ridge = reg.comparacion_ridge()

# %% [markdown]
# ### 6.5 Comparación SVM (rbf, linear, poly)

# %%
comp_svm = reg.comparacion_svm()

# %% [markdown]
# ### 6.6 Árbol de Decisión

# %%
err_arbol = reg.regresion_arbol()
err_arbol

# %% [markdown]
# ### 6.7 Random Forest

# %%
err_bosque = reg.regresion_bosque()
err_bosque

# %% [markdown]
# ### 6.8 Gradient Boosting

# %%
err_xgb = reg.regresion_xgboosting()
err_xgb

# %% [markdown]
# ## 7. Benchmark — Comparación de todos los algoritmos

# %%
resumen = reg.benchmark()
